# %% [markdown]
# # Trabajo final Digital Transformation - Python
#
# Python es un lenguaje de programación. En los _notebooks_ previos, casi todo el trabajo que hemos realizado es prácticamente interactivo, aunque en un par de ocasiones nos hemos visto obligados a utilizar funciones o bucles.
#
# En este _notebook_ aprenderemos los rudimentos de la programación en Python, comenzando con tipos de datos y terminando con la definición de funciones simples.

# %% [markdown]
# # 1. Importamos los paquetes para empezar a trabajar

# %%
import pandas as pd
import re
import numpy as np
import datetime
from datetime import datetime,date
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
pd.options.display.float_format = '{:,.1f}'.format
import matplotlib.dates as mdates
# %matplotlib inline
import matplotlib.ticker as mtick
from matplotlib.ticker import FuncFormatter
pd.options.display.float_format = '{:,.1f}'.format

# %% [markdown]
# # 2. Cargamos los archivos csv y los nombramos

# %% [markdown]
# ## 2.1. Cargamos las url de cada mes (Septiembre 2018 hasta Agosto 2019)

# %%
path_web0918='https://datos.madrid.es/egob/catalogo/210104-214-multas-circulacion-detalle.csv'
path_web1018='https://datos.madrid.es/egob/catalogo/210104-218-multas-circulacion-detalle.csv'
path_web1118='https://datos.madrid.es/egob/catalogo/210104-222-multas-circulacion-detalle.csv'
path_web1218='https://datos.madrid.es/egob/catalogo/210104-224-multas-circulacion-detalle.csv'
path_web0119='https://datos.madrid.es/egob/catalogo/210104-226-multas-circulacion-detalle.csv'
path_web0219='https://datos.madrid.es/egob/catalogo/210104-230-multas-circulacion-detalle.csv'
path_web0319='https://datos.madrid.es/egob/catalogo/210104-234-multas-circulacion-detalle.csv'
path_web0419='https://datos.madrid.es/egob/catalogo/210104-238-multas-circulacion-detalle.csv'
path_web0519='https://datos.madrid.es/egob/catalogo/210104-242-multas-circulacion-detalle.csv'
path_web0619='https://datos.madrid.es/egob/catalogo/210104-246-multas-circulacion-detalle.csv'
path_web0719='https://datos.madrid.es/egob/catalogo/210104-252-multas-circulacion-detalle.csv'
path_web0819='https://datos.madrid.es/egob/catalogo/210104-256-multas-circulacion-detalle.csv'

# %% [markdown]
# ## 2.2 Nombramos las cabeceras de las columnas de cada tabla

# %%
nombre_columnas0918=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas1018=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas1118=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas1218=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0119=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0219=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0319=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0419=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0519=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0619=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0719=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']
nombre_columnas0819=['GRAVEDAD','DIRECCION','MES','ANIO','HORA','IMPORTE_MULTA',
                     'DESCUENTO','PUNTOS','DENUNCIANTE','DESCRIPCION_INFRACCION',
                     'VELOCIDAD_LIMITE','VELOCIDAD_CIRCULACION','COORDENADA_X','COORDENADA_Y']

# %% [markdown]
# ## 2.3 Cargamos cada tabla por separado, debido a la ctd. de datos en cada una

# %% [markdown]
# ### 2.3.1 Setiembre 2018

# %% [markdown]
# #### 2.3.1.1 Cargamos el csv

# %%
set18 = pd.read_csv(path_web0918, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0918,skiprows=1)
set18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  HORA  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018  17.2
# 1  LEVE        CL PEDRO RICO F29                           9  2018  17.5
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018  19.1
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018  19.2
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018  10.1
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           60.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #### 2.3.1.2 Revisamos el tipo de variable "Hora" para analizarla

# %%
set18.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                      float64
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %% [markdown]
# #### 2.3.1.3 Convertimos la variable "Hora" a string para modificarla a formato "HH:00"

# %%
# Convertimos la variable a string

set18.HORA=set18.HORA.apply(lambda i: str(i))
set18.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

set18['HORA']=set18.HORA.apply(lambda i: i.replace('.',':'))
set18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018   17:2
# 1  LEVE        CL PEDRO RICO F29                           9  2018  17:47
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018  19:08
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018  19:16
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018  10:12
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           60.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

set18['HORA']=pd.to_datetime(set18['HORA'],format='%H:%M')
set18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018
# 1  LEVE        CL PEDRO RICO F29                           9  2018
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 17:02:00           90.0        SI       0  SER
# 1 1900-01-01 17:47:00           90.0        SI       0  SER
# 2 1900-01-01 19:08:00           90.0        SI       0  SER
# 3 1900-01-01 19:16:00           60.0        SI       0  SER
# 4 1900-01-01 10:12:00           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #### 2.3.1.4 Una vez convertida la variable en formato hora la estandarizamos para plotear y creamos una columna adicional para el ploteo final

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,set18.shape[0]):
    set18.set_value(n,'hora_entera',set18.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
# Hallamos el total de multas del mes

len(set18)
# Out:
# 199997

# %% [markdown]
# #### 2.3.1.5 Ploteamos el gráfico para el mes de Septiembre, para encontrar las horas pico de multas

# %%
set18_hist=set18['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora sep-18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_sep18',bbox_inches = 'tight')

# %% [markdown]
# #### 2.3.1.6 Ploteamos el gráfico para el mes de Septiembre, para encontrar el % por hora en el mes de Septiembre

# %%
set18_hist_porcentaje=set18['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Sep-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('set18_hora_porcentaje_sep18',bbox_inches = 'tight')

# %% [markdown]
# #### 2.3.1.3 Revisamos la variable "Puntos"

# %%
puntos_totales=set18.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 23,524 puntos

# %%
euros_totales=set18.IMPORTE_MULTA.sum()
print ('Importe total de multas antes de descuento: {:,.0f} euros'.format(euros_totales))
# Out:
# Importe total de multas antes de descuento: 19,534,120 euros

# %%
set18_euros=set18.sort_values('HORA').groupby("hora_entera",sort=False).IMPORTE_MULTA
fig1 = plt.figure()
ax1 = fig1.add_subplot(1,1,1)
ax1 = set18_euros.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Euros',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(set18_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Euros de multa por hora Set-18')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('euros_hora',bbox_inches = 'tight')

# %%
set18_puntos=set18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = set18_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Sep-18')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Sep18',bbox_inches = 'tight')

# %%
ratio_euros_set18=set18_euros.sum()/set18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_euros_set18.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('€/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de € por multa Sep-18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_euros_multa_Jul17',bbox_inches = 'tight')

# %%
ratio_puntos_set18=set18_puntos.sum()/set18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_set18.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Sep 18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Sep18',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.2 Octubre 2018

# %% [markdown]
# #### 2.3.2.1 Revisamos la variable "Puntos"

# %%
oct18 = pd.read_csv(path_web0918, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0918,skiprows=1)
oct18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  HORA  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018  17.2
# 1  LEVE        CL PEDRO RICO F29                           9  2018  17.5
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018  19.1
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018  19.2
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018  10.1
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           60.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos la variable a string

oct18.HORA=oct18.HORA.apply(lambda i: str(i))
oct18.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

oct18['HORA']=oct18.HORA.apply(lambda i: i.replace('.',':'))
oct18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018   17:2
# 1  LEVE        CL PEDRO RICO F29                           9  2018  17:47
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018  19:08
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018  19:16
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018  10:12
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           60.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

oct18['HORA']=pd.to_datetime(oct18['HORA'],format='%H:%M')
oct18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018
# 1  LEVE        CL PEDRO RICO F29                           9  2018
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 17:02:00           90.0        SI       0  SER
# 1 1900-01-01 17:47:00           90.0        SI       0  SER
# 2 1900-01-01 19:08:00           90.0        SI       0  SER
# 3 1900-01-01 19:16:00           60.0        SI       0  SER
# 4 1900-01-01 10:12:00           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,oct18.shape[0]):
    oct18.set_value(n,'hora_entera',oct18.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.2.4 Revisamos la variable "Puntos"


puntos_totales=oct18.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 23,524 puntos

# %% [markdown]
# #### 2.3.2.5 Ploteamos el gráfico para el mes de Octubre, para encontrar las horas pico de multas

# %%
oct18_hist=oct18['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora oct-18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_oct18',bbox_inches = 'tight')

# %% [markdown]
# #### 2.3.2.6 Ploteamos el gráfico para el mes de Octubre, para encontrar el % por hora en el mes de Octubre

# %%
oct18_hist_porcentaje=oct18['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Oct-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('oct18_hora_porcentaje_oct18',bbox_inches = 'tight')

# %%
#### 2.3.2.7 Revisamos la variable "Puntos"


puntos_totales=oct18.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 23,524 puntos

# %%
oct18_puntos=oct18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = set18_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Oct-18')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Oct18',bbox_inches = 'tight')

# %%
ratio_puntos_oct18=set18_puntos.sum()/set18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_oct18.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Oct 18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Oct18',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.3 Noviembre 2019

# %% [markdown]
# #### 2.3.2.1 Revisamos la variable "Puntos"

# %%
nov18 = pd.read_csv(path_web0918, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0918,skiprows=1)
nov18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  HORA  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018  17.2
# 1  LEVE        CL PEDRO RICO F29                           9  2018  17.5
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018  19.1
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018  19.2
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018  10.1
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           60.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos la variable a string

nov18.HORA=nov18.HORA.apply(lambda i: str(i))
nov18.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

nov18['HORA']=nov18.HORA.apply(lambda i: i.replace('.',':'))
nov18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018   17:2
# 1  LEVE        CL PEDRO RICO F29                           9  2018  17:47
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018  19:08
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018  19:16
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018  10:12
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           60.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

nov18['HORA']=pd.to_datetime(nov18['HORA'],format='%H:%M')
nov18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CL PEDRO RICO F33                           9  2018
# 1  LEVE        CL PEDRO RICO F29                           9  2018
# 2  LEVE        AV MONFORTE DE LEMOS 4                      9  2018
# 3  LEVE        AV MONFORTE DE LEMOS 2                      9  2018
# 4  LEVE        CL SOR ANGELA DE LA CRUZ 7                  9  2018
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 17:02:00           90.0        SI       0  SER
# 1 1900-01-01 17:47:00           90.0        SI       0  SER
# 2 1900-01-01 19:08:00           90.0        SI       0  SER
# 3 1900-01-01 19:16:00           60.0        SI       0  SER
# 4 1900-01-01 10:12:00           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
   
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,nov18.shape[0]):
    nov18.set_value(n,'hora_entera',nov18.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Noviembre, para encontrar las horas pico de multas

# %%
nov18_hist=nov18['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora nov-18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_nov18',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Noviembre, para encontrar el % por hora en el mes de Noviembre

# %%
nov18_hist_porcentaje=nov18['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Nov-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('set18_hora_porcentaje_sep18',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=nov18.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 23,524 puntos

# %%
nov18_puntos=nov18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = nov18_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Nov-18')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Nov18',bbox_inches = 'tight')

# %%
ratio_puntos_nov18=nov18_puntos.sum()/set18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_nov18.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Nov 18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Nov18',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.3 Diciembre 2018

# %% [markdown]
# #### 2.3.3.1 Revisamos la variable "Puntos"

# %%
dic18 = pd.read_csv(path_web1118, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas1118,skiprows=1)

# %%
# Convertimos la variable a string

dic18.HORA=dic18.HORA.apply(lambda i: str(i))
dic18.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

dic18['HORA']=dic18.HORA.apply(lambda i: i.replace('.',':'))
dic18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CL NUMANCIA 32                             11  2018  13:32
# 1  LEVE        CL CAROLINAS 6                             11  2018  14:24
# 2  GRAVE       CL ORENSE 83                               11  2018  13:02
# 3  LEVE        CL ORENSE 81                               11  2018  13:04
# 4  GRAVE       VERDOLAGA 5                                11  2018   13:3
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           60.0        SI       0  SER
# 1           60.0        SI       0  SER
# 2          200.0        SI       0  SER
# 3           90.0        SI       0  SER
# 4          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 1  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 2  ESTACIONAR EN DOBLE FILA.                     ...
# 3  ESTACIONAR EN CARRIL DECIRCULACIÓN.           ...
# 4  ESTACIONAR SOBRE LA ACERA OBSTACULIZANDO GRAVE...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

dic18['HORA']=pd.to_datetime(dic18['HORA'],format='%H:%M')
dic18.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CL NUMANCIA 32                             11  2018
# 1  LEVE        CL CAROLINAS 6                             11  2018
# 2  GRAVE       CL ORENSE 83                               11  2018
# 3  LEVE        CL ORENSE 81                               11  2018
# 4  GRAVE       VERDOLAGA 5                                11  2018
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 13:32:00           60.0        SI       0  SER
# 1 1900-01-01 14:24:00           60.0        SI       0  SER
# 2 1900-01-01 13:02:00          200.0        SI       0  SER
# 3 1900-01-01 13:04:00           90.0        SI       0  SER
# 4 1900-01-01 13:03:00          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 1  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 2  ESTACIONAR EN DOBLE FILA.                     ...
# 3  ESTACIONAR EN CARRIL DECIRCULACIÓN.           ...
# 4  ESTACIONAR SOBRE LA ACERA OBSTACULIZANDO GRAVE...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,dic18.shape[0]):
    dic18.set_value(n,'hora_entera',dic18.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Diciembre, para encontrar las horas pico de multas

# %%
dic18_hist=set18['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=dic18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora dic-18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_dic18',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Diciembre, para encontrar el % por hora en el mes de Diciembre

# %%
dic18_hist_porcentaje=set18['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=dic18_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Dic-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('dic18_hora_porcentaje_dic18',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=dic18.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 22,139 puntos

# %%
dic18_puntos=dic18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = dic18_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Dic-18')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Sep18',bbox_inches = 'tight')

# %%
ratio_puntos_dic18=set18_puntos.sum()/dic18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_dic18.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Dic 18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Dic18',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.5 Enero 2019

# %% [markdown]
# #### 2.3.5.1 Revisamos la variable "Puntos"

# %%
ene19 = pd.read_csv(path_web0119, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0119,skiprows=1)

# %%
# Convertimos la variable a string

ene19.HORA=ene19.HORA.apply(lambda i: str(i))
ene19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

ene19['HORA']=ene19.HORA.apply(lambda i: i.replace('.',':'))
ene19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        SAN RESTITUTO 24                            1  2019  16:12
# 1  LEVE        LOMBIA-JORGE JUAN                           1  2019  17:35
# 2  LEVE        CL MULLER 36                                1  2019  10:47
# 3  LEVE        SANTA ISABEL 31                             1  2019   1:15
# 4  GRAVE       CAUNEDO 27                                  1  2019    9:4
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  POLICIA MUNICIPAL
# 1           60.0        SI       0  POLICIA MUNICIPAL
# 2           90.0        SI       0  SER
# 3           90.0        SI       0  POLICIA MUNICIPAL
# 4          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 1  ESTACIONAR MOTOCICLETA O CICLOMOTOR SOBRE LA A...
# 2  ESTACIONAR SOBRE LA ACERA.                    ...
# 3  ESTACIONAR EN LUGAR RESERVADO TEMPORALMENTE PA...
# 4  ESTACIONAR EN ZONA SEŃALIZADA PARA USO EXCLUSI...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

ene19['HORA']=pd.to_datetime(ene19['HORA'],format='%H:%M')
ene19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        SAN RESTITUTO 24                            1  2019
# 1  LEVE        LOMBIA-JORGE JUAN                           1  2019
# 2  LEVE        CL MULLER 36                                1  2019
# 3  LEVE        SANTA ISABEL 31                             1  2019
# 4  GRAVE       CAUNEDO 27                                  1  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 16:12:00           90.0        SI       0  POLICIA MUNICIPAL
# 1 1900-01-01 17:35:00           60.0        SI       0  POLICIA MUNICIPAL
# 2 1900-01-01 10:47:00           90.0        SI       0  SER
# 3 1900-01-01 01:15:00           90.0        SI       0  POLICIA MUNICIPAL
# 4 1900-01-01 09:04:00          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 1  ESTACIONAR MOTOCICLETA O CICLOMOTOR SOBRE LA A...
# 2  ESTACIONAR SOBRE LA ACERA.                    ...
# 3  ESTACIONAR EN LUGAR RESERVADO TEMPORALMENTE PA...
# 4  ESTACIONAR EN ZONA SEŃALIZADA PARA USO EXCLUSI...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,ene19.shape[0]):
    ene19.set_value(n,'hora_entera',ene19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Enero, para encontrar las horas pico de multas

# %%
ene19_hist=set18['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora ene19-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_ene19',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Enero, para encontrar el % por hora en el mes de Enero

# %%
ene19_hist_porcentaje=set18['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ene19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Ene-19')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('Ene19_hora_porcentaje_ene19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=ene19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 19,476 puntos

# %%
ene19_puntos=set18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = ene19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Ene-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Ene19',bbox_inches = 'tight')

# %%
ratio_puntos_ene19=ene19_puntos.sum()/set18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_ene19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Ene 19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Sep18',bbox_inches = 'tight')

# %%
### 2.3.6 Febrero 2019

# %%
#### 2.3.6.1 Revisamos la variable "Puntos"

# %%
feb19 = pd.read_csv(path_web0219, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0219,skiprows=1)

# %%
# Convertimos la variable a string

feb19.HORA=feb19.HORA.apply(lambda i: str(i))
feb19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

feb19['HORA']=feb19.HORA.apply(lambda i: i.replace('.',':'))
feb19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  GRAVE       FTE CARRANTONA ESQ HAC.PAVONES              2  2019   9:04
# 1  LEVE        CL NUMANCIA 12                              2  2019  13:17
# 2  GRAVE       SINESIO DELGADO GTA P. CEBRERO              2  2019   9:46
# 3  GRAVE       VIA LUSITANA - PL ELIPTICA                  2  2019  14:03
# 4  GRAVE       VIA LUSITANA - PL ELIPTICA                  2  2019  16:41
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0          200.0        SI       4  AGENTES DE MOVILIDAD
# 1           30.0        SI       0  SER
# 2          200.0        SI       4  AGENTES DE MOVILIDAD
# 3          200.0        SI       4  AGENTES DE MOVILIDAD
# 4          200.0        SI       4  AGENTES DE MOVILIDAD
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
# 1  ESTACIONAR CON AUTORIZACIÓN EN LUGAR HABILITAD...
# 2  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
# 3  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
# 4  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3                          439132.53   4470910.90
# 4                          439132.53   4470910.90

# %%
# Convertimos los string a formato fecha-hora

feb19['HORA']=pd.to_datetime(feb19['HORA'],format='%H:%M')
feb19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  GRAVE       FTE CARRANTONA ESQ HAC.PAVONES              2  2019
# 1  LEVE        CL NUMANCIA 12                              2  2019
# 2  GRAVE       SINESIO DELGADO GTA P. CEBRERO              2  2019
# 3  GRAVE       VIA LUSITANA - PL ELIPTICA                  2  2019
# 4  GRAVE       VIA LUSITANA - PL ELIPTICA                  2  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 09:04:00          200.0        SI       4  AGENTES DE MOVILIDAD
# 1 1900-01-01 13:17:00           30.0        SI       0  SER
# 2 1900-01-01 09:46:00          200.0        SI       4  AGENTES DE MOVILIDAD
# 3 1900-01-01 14:03:00          200.0        SI       4  AGENTES DE MOVILIDAD
# 4 1900-01-01 16:41:00          200.0        SI       4  AGENTES DE MOVILIDAD
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
# 1  ESTACIONAR CON AUTORIZACIÓN EN LUGAR HABILITAD...
# 2  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
# 3  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
# 4  REBASAR UN SEMÁFORO EN FASE ROJA.             ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3                          439132.53   4470910.90
# 4                          439132.53   4470910.90

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,feb19.shape[0]):
    feb19.set_value(n,'hora_entera',feb19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Febrero, para encontrar las horas pico de multas

# %%
feb19_hist=set18['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=feb19_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora feb-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_feb19',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Febrero, para encontrar el % por hora en el mes de Febrero

# %%
Feb19_hist_porcentaje=set18['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora feb-19')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('feb19_hora_porcentaje_sep18',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=feb19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 20,732 puntos

# %%
feb19_puntos=feb19.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = feb19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Feb-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Sep18',bbox_inches = 'tight')

# %%
ratio_puntos_feb19=feb19_puntos.sum()/feb19_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_feb19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Feb 19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Sep18',bbox_inches = 'tight')

# %%
### 2.3.7 Marzo 2019

# %%
#### 2.3.7.1 Revisamos la variable "Puntos"

# %%
mar19 = pd.read_csv(path_web0319, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0319,skiprows=1)

# %%
# Convertimos la variable a string

mar19.HORA=mar19.HORA.apply(lambda i: str(i))
mar19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

mar19['HORA']=mar19.HORA.apply(lambda i: i.replace('.',':'))
mar19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        AEROPUERTO SALIDA T 1                       3  2019   12:3
# 1  LEVE        AEROPUERTO SALIDA T 1                       3  2019   12:3
# 2  LEVE        AEROPUERTO SALIDA T 1                       3  2019   12:3
# 3  LEVE        PZ JOSE DE VILLARREAL                       3  2019  12:15
# 4  GRAVE       HERMINIO PUERTAS 50                         3  2019  20:33
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  POLICIA MUNICIPAL
# 1           90.0        SI       0  POLICIA MUNICIPAL
# 2           90.0        SI       0  POLICIA MUNICIPAL
# 3           90.0        SI       0  POLICIA MUNICIPAL
# 4          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 1  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 2  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 3  ESTACIONAR SOBRE LA ACERA.                    ...
# 4  ESTACIONAR EN ZONA SEŃALIZADA PARA USO EXCLUSI...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

mar19['HORA']=pd.to_datetime(mar19['HORA'],format='%H:%M')
mar19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        AEROPUERTO SALIDA T 1                       3  2019
# 1  LEVE        AEROPUERTO SALIDA T 1                       3  2019
# 2  LEVE        AEROPUERTO SALIDA T 1                       3  2019
# 3  LEVE        PZ JOSE DE VILLARREAL                       3  2019
# 4  GRAVE       HERMINIO PUERTAS 50                         3  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 12:03:00           90.0        SI       0  POLICIA MUNICIPAL
# 1 1900-01-01 12:03:00           90.0        SI       0  POLICIA MUNICIPAL
# 2 1900-01-01 12:03:00           90.0        SI       0  POLICIA MUNICIPAL
# 3 1900-01-01 12:15:00           90.0        SI       0  POLICIA MUNICIPAL
# 4 1900-01-01 20:33:00          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 1  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 2  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 3  ESTACIONAR SOBRE LA ACERA.                    ...
# 4  ESTACIONAR EN ZONA SEŃALIZADA PARA USO EXCLUSI...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,mar19.shape[0]):
    mar19.set_value(n,'hora_entera',mar19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Marzo, para encontrar las horas pico de multas

# %%
Mar19_hist=mar19['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora mar-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_sep18',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Marzo, para encontrar el % por hora en el mes de Marzo

# %%
mar19_hist_porcentaje=mar19['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=mar19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Sep-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('set18_hora_porcentaje_mar19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=mar19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 21,502 puntos

# %%
mar19_puntos=set18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = mar19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Mar-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Mar19',bbox_inches = 'tight')

# %%
ratio_puntos_mar19=mar19_puntos.sum()/set18_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_mar19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Mar 18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Mar19',bbox_inches = 'tight')

# %%
g = sns.pairplot(, hue="Species", diag_kind="hist")

# %% [markdown]
# ### 2.3.8 Abril 2019

# %%
abr19 = pd.read_csv(path_web0419, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0419,skiprows=1)

# %%
# Convertimos la variable a string

abr19.HORA=abr19.HORA.apply(lambda i: str(i))
abr19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

abr19['HORA']=abr19.HORA.apply(lambda i: i.replace('.',':'))
abr19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CL P. JUSTO DORADO DELLMANS 4               4  2019  14:55
# 1  LEVE        CL JUAN ESPLANDIU 13                        4  2019  14:26
# 2  LEVE        PZ ANGEL CARBAJO 4                          4  2019  13:22
# 3  LEVE        CL ALONSO CANO 18                           4  2019    9:3
# 4  LEVE        CL BRETON DE LOS HERREROS 12                4  2019    9:2
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1           60.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           90.0        SI       0  SER
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 2  ESTACIONAR EN CARRIL DE CIRCULACIÓN.          ...
# 3  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

abr19['HORA']=pd.to_datetime(abr19['HORA'],format='%H:%M')
abr19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CL P. JUSTO DORADO DELLMANS 4               4  2019
# 1  LEVE        CL JUAN ESPLANDIU 13                        4  2019
# 2  LEVE        PZ ANGEL CARBAJO 4                          4  2019
# 3  LEVE        CL ALONSO CANO 18                           4  2019
# 4  LEVE        CL BRETON DE LOS HERREROS 12                4  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 14:55:00           90.0        SI       0  SER
# 1 1900-01-01 14:26:00           60.0        SI       0  SER
# 2 1900-01-01 13:22:00           90.0        SI       0  SER
# 3 1900-01-01 09:03:00           90.0        SI       0  SER
# 4 1900-01-01 09:02:00           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 2  ESTACIONAR EN CARRIL DE CIRCULACIÓN.          ...
# 3  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,abr19.shape[0]):
    abr19.set_value(n,'hora_entera',abr19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %% [markdown]
# #### 2.3.1.5 Ploteamos el gráfico para el mes de Abril, para encontrar las horas pico de multas

# %%
Abr19_hist=abr19['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=set18_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora abr-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_abr19',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Abril, para encontrar el % por hora en el mes de Abril

# %%
Abr19_hist_porcentaje=abr19['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=Abr19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Abr-19')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('Abr19_hora_porcentaje_abr19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=abr19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 20,419 puntos

# %%
abr19_puntos=abr19.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = abr19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Abr-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Abr19',bbox_inches = 'tight')

# %%
ratio_puntos_abr19=abr19_puntos.sum()/Abr19_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_abr19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Abr 18')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Abr18',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.9 Mayo 2019

# %%
may19 = pd.read_csv(path_web0519, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0519,skiprows=1)

# %%
# Convertimos la variable a string

may19.HORA=may19.HORA.apply(lambda i: str(i))
may19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

may19['HORA']=may19.HORA.apply(lambda i: i.replace('.',':'))
may19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  GRAVE       ARROYO VALDECELADA                          5  2019   19:1
# 1  GRAVE       ALESANCO-SANCHEZ PRECIADO                   5  2019   11:0
# 2  LEVE        ALESANCO-SANCHEZ PRECIADO                   5  2019  11:01
# 3  GRAVE       QUINTANA 26                                 5  2019   13:0
# 4  GRAVE       FRANCOS RODRIGUEZ                           5  2019  14:27
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0          200.0        SI       0  POLICIA MUNICIPAL
# 1          200.0        SI       0  POLICIA MUNICIPAL
# 2           90.0        SI       0  POLICIA MUNICIPAL
# 3          200.0        SI       0  POLICIA MUNICIPAL
# 4          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR EN CARRIL DECIRCULACIÓN OBSTACULIZA...
# 1  ESTACIONAR EN CARRIL DECIRCULACIÓN OBSTACULIZA...
# 2  ESTACIONAR EN CARRIL DE CIRCULACIÓN.          ...
# 3  ESTACIONAR OBSTACULIZANDO LA UTILIZACIÓN DE UN...
# 4  ESTACIONAR SOBRE LA ACERA OBSTACULIZANDO GRAVE...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

may19['HORA']=pd.to_datetime(may19['HORA'],format='%H:%M')
may19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  GRAVE       ARROYO VALDECELADA                          5  2019
# 1  GRAVE       ALESANCO-SANCHEZ PRECIADO                   5  2019
# 2  LEVE        ALESANCO-SANCHEZ PRECIADO                   5  2019
# 3  GRAVE       QUINTANA 26                                 5  2019
# 4  GRAVE       FRANCOS RODRIGUEZ                           5  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 19:01:00          200.0        SI       0  POLICIA MUNICIPAL
# 1 1900-01-01 11:00:00          200.0        SI       0  POLICIA MUNICIPAL
# 2 1900-01-01 11:01:00           90.0        SI       0  POLICIA MUNICIPAL
# 3 1900-01-01 13:00:00          200.0        SI       0  POLICIA MUNICIPAL
# 4 1900-01-01 14:27:00          200.0        SI       0  POLICIA MUNICIPAL
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR EN CARRIL DECIRCULACIÓN OBSTACULIZA...
# 1  ESTACIONAR EN CARRIL DECIRCULACIÓN OBSTACULIZA...
# 2  ESTACIONAR EN CARRIL DE CIRCULACIÓN.          ...
# 3  ESTACIONAR OBSTACULIZANDO LA UTILIZACIÓN DE UN...
# 4  ESTACIONAR SOBRE LA ACERA OBSTACULIZANDO GRAVE...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,may19.shape[0]):
    may19.set_value(n,'hora_entera',may19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Mayo, para encontrar las horas pico de multas

# %%
may19_hist=may19['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=may19_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora may-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_may19',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Mayo, para encontrar el % por hora en el mes de Mayo

# %%
may19_hist_porcentaje=may19['hora_entera'].value_counts().sort_index(axis=0)/len(set18)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=may19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora May-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('may19_hora_porcentaje_may19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=may19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 24,121 puntos

# %%
may19_puntos=may19.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = may19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora May-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_May19',bbox_inches = 'tight')

# %%
ratio_puntos_may19=may19_puntos.sum()/may19_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_may19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora May 19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_May19',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.10 Junio 2019

# %%
jun19 = pd.read_csv(path_web0619, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0619,skiprows=1)

# %%
# Convertimos la variable a string

jun19.HORA=jun19.HORA.apply(lambda i: str(i))
jun19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

jun19['HORA']=jun19.HORA.apply(lambda i: i.replace('.',':'))
jun19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  GRAVE       M 30 KM 10,300 XC CARRIL 3                  6  2019  11:29
# 1  LEVE        CL SANTA ENGRACIA 179                       6  2019   17:1
# 2  LEVE        CL BRAVO MURILLO 46                         6  2019  18:02
# 3  LEVE        CL SANTA ENGRACIA 173                       6  2019  19:05
# 4  GRAVE       AV SENECA S/N                               6  2019  10:56
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0          500.0        SI       6  POLICIA MUNICIPAL
# 1           90.0        SI       0  SER
# 2           60.0        SI       0  SER
# 3           90.0        SI       0  SER
# 4          200.0        SI       0  AGENTES DE MOVILIDAD
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  SOBREPASAR LA VELOCIDAD MÁXIMA EN VÍAS LIMITAD...               70
# 1  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 2  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 3  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 4  ESTACIONAR EN CARRIL RESERVADO PARA USO, PARAD...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0                   138
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

jun19['HORA']=pd.to_datetime(jun19['HORA'],format='%H:%M')
jun19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  GRAVE       M 30 KM 10,300 XC CARRIL 3                  6  2019
# 1  LEVE        CL SANTA ENGRACIA 179                       6  2019
# 2  LEVE        CL BRAVO MURILLO 46                         6  2019
# 3  LEVE        CL SANTA ENGRACIA 173                       6  2019
# 4  GRAVE       AV SENECA S/N                               6  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 11:29:00          500.0        SI       6  POLICIA MUNICIPAL
# 1 1900-01-01 17:01:00           90.0        SI       0  SER
# 2 1900-01-01 18:02:00           60.0        SI       0  SER
# 3 1900-01-01 19:05:00           90.0        SI       0  SER
# 4 1900-01-01 10:56:00          200.0        SI       0  AGENTES DE MOVILIDAD
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  SOBREPASAR LA VELOCIDAD MÁXIMA EN VÍAS LIMITAD...               70
# 1  ESTACIONAR EN LUGAR PROHIBIDO.                ...
# 2  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
# 3  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 4  ESTACIONAR EN CARRIL RESERVADO PARA USO, PARAD...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0                   138
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,jun19.shape[0]):
    jun19.set_value(n,'hora_entera',jun19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Junio, para encontrar las horas pico de multas

# %%
jun19_hist=jun19['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=jun19_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora jun-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_jun19',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Junio, para encontrar el % por hora en el mes de Junio

# %%
jun19_hist_porcentaje=jun19['hora_entera'].value_counts().sort_index(axis=0)/len(jun19)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=jun19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Jun-19')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('jun19_hora_porcentaje_jun19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=jun19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 22,143 puntos

# %%
jun19_puntos=jun19.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = jun19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Jun-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Jun19',bbox_inches = 'tight')

# %%
ratio_puntos_jun19=jun19_puntos.sum()/jun19_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_jun19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Jun 19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Sep18',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.11 Julio 2019

# %%
jul19 = pd.read_csv(path_web0719, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0719,skiprows=1)

# %%
# Convertimos la variable a string

jul19.HORA=jul19.HORA.apply(lambda i: str(i))
jul19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

jul19['HORA']=jul19.HORA.apply(lambda i: i.replace('.',':'))
jul19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CALLE TOLEDO 123                            7  2019   0:46
# 1  LEVE        CL PEDRO TEIXEIRA 16                        7  2019  18:11
# 2  LEVE        CL PEDRO TEIXEIRA 10                        7  2019  18:51
# 3  LEVE        CL PEDRO TEIXEIRA 10                        7  2019  19:06
# 4  LEVE        CL SAN GERMAN 7                             7  2019  19:27
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  AGENTES DE MOVILIDAD
# 1           90.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           90.0        SI       0  SER
# 4           60.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ACCEDER A MADRID CENTRAL SIN AUTORIZACIÓN.    ...
# 1  ESTACIONAR EN CARRIL DE CIRCULACIÓN.          ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 4  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

jul19['HORA']=pd.to_datetime(jul19['HORA'],format='%H:%M')
jul19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CALLE TOLEDO 123                            7  2019
# 1  LEVE        CL PEDRO TEIXEIRA 16                        7  2019
# 2  LEVE        CL PEDRO TEIXEIRA 10                        7  2019
# 3  LEVE        CL PEDRO TEIXEIRA 10                        7  2019
# 4  LEVE        CL SAN GERMAN 7                             7  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 00:46:00           90.0        SI       0  AGENTES DE MOVILIDAD
# 1 1900-01-01 18:11:00           90.0        SI       0  SER
# 2 1900-01-01 18:51:00           90.0        SI       0  SER
# 3 1900-01-01 19:06:00           90.0        SI       0  SER
# 4 1900-01-01 19:27:00           60.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ACCEDER A MADRID CENTRAL SIN AUTORIZACIÓN.    ...
# 1  ESTACIONAR EN CARRIL DE CIRCULACIÓN.          ...
# 2  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 3  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 4  ESTACIONAR CON AUTORIZACIÓN NO VÁLIDA.        ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,jul19.shape[0]):
    jul19.set_value(n,'hora_entera',jul19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Septiembre, para encontrar las horas pico de multas

# %%
jul19_hist=jul19['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=jul19_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora jul-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_jul19',bbox_inches = 'tight')

# %%
jul19_hist_porcentaje=jul19['hora_entera'].value_counts().sort_index(axis=0)/len(jul19)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=jul19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Jul-19')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('jul19_hora_porcentaje_jul19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=jul19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 22,249 puntos

# %%
jul19_puntos=set18.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = jul19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Jul-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Jul19',bbox_inches = 'tight')

# %%
ratio_puntos_jul19=jul19_puntos.sum()/jul19_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_jul19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Jul 19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Jul19',bbox_inches = 'tight')

# %% [markdown]
# ### 2.3.12 Agosto 2019

# %%
ago19 = pd.read_csv(path_web0819, sep=';', encoding='windows-1250', 
                    index_col=False, header=None,names=nombre_columnas0819,skiprows=1)

# %%
# Convertimos la variable a string

ago19.HORA=ago19.HORA.apply(lambda i: str(i))
ago19.dtypes
# Out:
# GRAVEDAD                   object
# DIRECCION                  object
# MES                         int64
# ANIO                        int64
# HORA                       object
# IMPORTE_MULTA             float64
# DESCUENTO                  object
# PUNTOS                      int64
# DENUNCIANTE                object
# DESCRIPCION_INFRACCION     object
# VELOCIDAD_LIMITE           object
# VELOCIDAD_CIRCULACION      object
# COORDENADA_X               object
# COORDENADA_Y               object
# dtype: object

# %%
# Reemplazamos los "." por ":"

ago19['HORA']=ago19.HORA.apply(lambda i: i.replace('.',':'))
ago19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO   HORA  \
# 0  LEVE        CL CORAZON DE MARIA 65                      8  2019   9:37
# 1  GRAVE       CL ARZOBISPO MORCILLO 1                     8  2019  10:37
# 2  LEVE        CL ARZOBISPO MORCILLO 1                     8  2019  10:49
# 3  LEVE        CALLE ALCALA 51                             8  2019  18:07
# 4  LEVE        PO LA HABANA 42                             8  2019   9:44
#
#    IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0           90.0        SI       0  SER
# 1          200.0        SI       0  SER
# 2           90.0        SI       0  SER
# 3           90.0        SI       0  AGENTES DE MOVILIDAD
# 4           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR EN CARRIL RESERVADO PARA USO, PARAD...
# 2  ESTACIONAR SOBRE LA ACERA.                    ...
# 3  ACCEDER A MADRID CENTRAL SIN AUTORIZACIÓN.    ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Convertimos los string a formato fecha-hora

ago19['HORA']=pd.to_datetime(ago19['HORA'],format='%H:%M')
ago19.head()
# Out:
#      GRAVEDAD                                 DIRECCION  MES  ANIO  \
# 0  LEVE        CL CORAZON DE MARIA 65                      8  2019
# 1  GRAVE       CL ARZOBISPO MORCILLO 1                     8  2019
# 2  LEVE        CL ARZOBISPO MORCILLO 1                     8  2019
# 3  LEVE        CALLE ALCALA 51                             8  2019
# 4  LEVE        PO LA HABANA 42                             8  2019
#
#                  HORA  IMPORTE_MULTA DESCUENTO  PUNTOS           DENUNCIANTE  \
# 0 1900-01-01 09:37:00           90.0        SI       0  SER
# 1 1900-01-01 10:37:00          200.0        SI       0  SER
# 2 1900-01-01 10:49:00           90.0        SI       0  SER
# 3 1900-01-01 18:07:00           90.0        SI       0  AGENTES DE MOVILIDAD
# 4 1900-01-01 09:44:00           90.0        SI       0  SER
#
#                               DESCRIPCION_INFRACCION VELOCIDAD_LIMITE  \
# 0  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
# 1  ESTACIONAR EN CARRIL RESERVADO PARA USO, PARAD...
# 2  ESTACIONAR SOBRE LA ACERA.                    ...
# 3  ACCEDER A MADRID CENTRAL SIN AUTORIZACIÓN.    ...
# 4  ESTACIONAR, SIN LA CORRESPONDIENTE AUTORIZACIÓ...
#
#   VELOCIDAD_CIRCULACION COORDENADA_X COORDENADA_Y
# 0
# 1
# 2
# 3
# 4

# %%
# Solo utilizaremos las horas descartando los minutos y crearemos una columna para ingresarla al ploteo más adelante

for n in range(0,set18.shape[0]):
    ago19.set_value(n,'hora_entera',ago19.loc[n,'HORA'].strftime('%H')+':00');
# Out:
# C:\Users\Pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
#### 2.3.1.5 Ploteamos el gráfico para el mes de Septiembre, para encontrar las horas pico de multas

# %%
ago19_hist=ago19['hora_entera'].value_counts().sort_index(axis=0)
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ago19_hist.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Número de multas',size=16)
ax.grid(axis='y')
ax.set_title('Multas acumuladas por hora ago-19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('multas_hora_ago19',bbox_inches = 'tight')

# %%
#### 2.3.1.6 Ploteamos el gráfico para el mes de Agosto, para encontrar el % por hora en el mes de Agosto

# %%
ago19_hist_porcentaje=ago19['hora_entera'].value_counts().sort_index(axis=0)/len(ago19)*100
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ago19_hist_porcentaje.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('% multas',size=16)
ax.grid(axis='y')
ax.set_title('Porcentajes de multas en cada hora Ago-18')
fmt = '%3.1f%%'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('ago19_hora_porcentaje_ago19',bbox_inches = 'tight')

# %%
#### 2.3.1.3 Revisamos la variable "Puntos"


puntos_totales=ago19.PUNTOS.sum()
print ('Puntos total perdidos: {:,.0f} puntos'.format(puntos_totales))
# Out:
# Puntos total perdidos: 19,373 puntos

# %%
ago19_puntos=ago19.sort_values('HORA').groupby("hora_entera",sort=False).PUNTOS
fig1 = plt.figure(1,(7,4))
ax1 = fig1.add_subplot(1,1,1)
ax1 = ago19_puntos.sum().plot.bar()
ax1.locator_params(axis='y',nbins=10)
ax1.set_xlabel('Hora del día')
ax1.set_ylabel('Puntos',size=16)
ax1.tick_params(axis='x',direction='out', length=6, width=2, colors='black')
#ax1.set_xticklabels(multas_euros['hora_entera'])
ax1.grid(axis='y')
ax1.set_title('Distribucion de Puntos por hora Ago-19')
fig1.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig1.savefig('puntos_hora_Ago19',bbox_inches = 'tight')

# %%
ratio_puntos_ago19=ago19_puntos.sum()/ago19_hist
fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)
ax=ratio_puntos_ago19.plot.bar()
ax.locator_params(axis='y',nbins=10)
ax.set_xlabel('Hora del día')
ax.set_ylabel('Puntos/multa',size=16)
ax.grid(axis='y')
ax.set_title('Media de puntos por multas en cada hora Ago 19')
fig.suptitle('Fuente: Ayuntamiento de Madrid, http://datos.madrid.es',size=10,x=1,y=-0.01)
fig.savefig('media_puntos_multa_Ago19',bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g = sns.pairplot(ago19, hue="GRAVEDAD", diag_kind="hist")

# %%
from random import random
import matplotlib.pyplot as plt

g = sns.PairGrid(set18)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);

# %%
#set18 = pd.read_csv('set18.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#oct18 = pd.read_csv('oct18.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#nov18 = pd.read_csv('nov18.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#dic18 = pd.read_csv('dic18.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#ene19 = pd.read_csv('ene19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#feb19 = pd.read_csv('feb19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#mar19 = pd.read_csv('mar19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#abr19 = pd.read_csv('abr19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#may19 = pd.read_csv('may19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#jun19 = pd.read_csv('jun19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#jul19 = pd.read_csv('jul19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)
#ago19 = pd.read_csv('ago19.csv', sep=';', encoding='windows-1250', index_col=False, header=0)

# %% [markdown]
# ## 2.1 Verificamos el nombre de las variables para todos los csv

# %%
column_names0918=set18.columns
print(column_names0918)
column_names1018=oct18.columns
print(column_names1018)
column_names1118=nov18.columns
print(column_names1118)
column_names1218=dic18.columns
print(column_names1218)
column_names0119=ene19.columns
print(column_names0119)
column_names0219=feb19.columns
print(column_names0219)
column_names0319=mar19.columns
print(column_names0319)
column_names0419=abr19.columns
print(column_names0419)
column_names0519=may19.columns
print(column_names0519)
column_names0619=jun19.columns
print(column_names0619)
column_names0719=jul19.columns
print(column_names0719)
column_names0819=ago19.columns
print(column_names0819)
# Out:
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y', 'hora_entera'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')
# Index(['GRAVEDAD', 'DIRECCION', 'MES', 'ANIO', 'HORA', 'IMPORTE_MULTA',
#        'DESCUENTO', 'PUNTOS', 'DENUNCIANTE', 'DESCRIPCION_INFRACCION',
#        'VELOCIDAD_LIMITE', 'VELOCIDAD_CIRCULACION', 'COORDENADA_X',
#        'COORDENADA_Y'],
#       dtype='object')

# %% [markdown]
# # 3. Cambio de nombre a las variables (columnas)

# %% [markdown]
# ## 3.2. Concatenamos los csv para trabajar en un solo archivo

# %%
multas = pd.concat ([set18, oct18, nov18, dic18, ene19, feb19, mar19, abr19, may19, jun19, jul19, ago19])
multas

# %% [markdown]
# ## 3.4. Obtenemos el nombre de las variables

# %%
column_names = multas.columns
print(column_names)

# %% [markdown]
# # 4. Comprobamos que las variables no se repitan

# %%
for i in column_names:
  print('{} is unique: {}'.format(i, TotalMultas[i].is_unique))
print(column_names)

# %% [markdown]
# # 5. Verificamos si existen valores nulos por variable

# %%
print (multas['Gravedad'].isnull())
print (multas['Dirección'].isnull())
print (multas['Mes'].isnull())
print (multas['Año'].isnull())
print (multas['Hora'].isnull())
print (multas['Importe multa'].isnull())
print (multas['Descuento'].isnull())
print (multas['Puntos'].isnull())
print (multas['Denunciante'].isnull())
print (multas['Descripción infracción'].isnull())
print (multas['Velocidad límite'].isnull())
print (multas['Velocidad circulación'].isnull())
print (multas['Coordenada x'].isnull())
print (multas['Coordenada y'].isnull())

# %% [markdown]
# ## 5.1 Para comprobar en toda la tabla se hace lo siguiente:

# %%
# Existen valores nulos?
print (multas.isnull().values.any())
print (multas.isnull().sum())
# Se imprime la cantidad si hubiese de valores nulos
print (multas.isnull().sum().sum())

# %%
# Escribe el __DataFrame__ a CSV
multas.to_csv('multas1819.csv', index=False)

# %%
# Para asegurarse de que todo se vea bien.
#multas_2018_2019= pd.read_csv('multasS18A19.csv', keep_default_na=False, na_values=[""])
#multas_2018_2019

# %%
multas.columns

# %%
for n in range(0,multas_2018_2019.shape[0]):
    TotalMultas.set_value(n,'hora_entera',TotalMultas.loc[n,'Hora'].strftime('%H')+':00');
